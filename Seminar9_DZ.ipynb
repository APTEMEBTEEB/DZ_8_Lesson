# %% [markdown]
# <a href="https://colab.research.google.com/github/APTEMEBTEEB/DZ_8_Lesson/blob/main/Seminar9_DZ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Задание 1.
# 1. Загрузите таблицу из файла advertising_1.csv и сохраните её в датафрейм adv1_df.
# 2. Укажите в качестве индекса столбец Number.
# 3. Выведите на экран первые десять строк.

# %%
import pandas as pd

# %%
adv1_df = pd.read_csv('/content/advertising_1.csv', index_col='Number')

# %%
adv1_df.head(10)
# Out:
#         Daily Time Spent on Site  Daily Internet Usage  \
# Number
# 5                          68.95                256.09
# 6                          80.23                193.77
# 8                          74.15                245.89
# 9                            NaN                225.58
# 10                         59.99                226.74
# 11                         88.91                208.36
# 12                           NaN                131.76
# 13                         74.53                   NaN
# 14                         69.88                183.82
# 15                         47.64                122.02
#
#                                 Ad Topic Line  Clicked on Ad
# Number
# 5          Cloned 5thgeneration orchestration              0
# 6          Monitored national standardization              0
# 8       Triple-buffered reciprocal time-frame              0
# 9               Robust logistical utilization              0
# ...

# %% [markdown]
# ## Задание 2.
# 1. Выведите размер датафрейма adv1_df и cреднее ежедневное время
# нахождения в интернете пользователя под номером 8.

# %%
adv1_df.shape
# Out:
# (500, 4)

# %%
adv1_df.loc[8, 'Daily Internet Usage']
# Out:
# 245.89

# %% [markdown]
# ## Задание 3.
# 1. Загрузите таблицу из файла advertising_2.csv и сохраните её в датафрейм
# adv2_df. Укажите в качестве индекса стоблец Number.
# 2. Выведите на экран строки для пользователей с номерами с 533-го по 536-й.

# %%
adv2_df = pd.read_csv('/content/advertising_2.csv', index_col='Number')

# %%
adv2_df
# Out:
#         Daily Time Spent on Site  Daily Internet Usage  \
# Number
# 530                          NaN                165.27
# 531                        43.65                   NaN
# 532                        59.61                198.45
# 533                        46.61                   NaN
# 534                          NaN                162.03
# ...                          ...                   ...
# 735                        65.53                190.17
# 736                        61.87                   NaN
# 737                        83.16                   NaN
# 738                        44.11                121.24
# 739                        56.57                131.98
#
#                                        Ad Topic Line  Clicked on Ad
# Number
# 530                 Re-engineered impactful software              0
# 531              Business-focused background synergy              1
# 532     Future-proofed coherent budgetary management              0
# ...

# %%
adv2_df.loc[533:536]
# Out:
#         Daily Time Spent on Site  Daily Internet Usage  \
# Number
# 533                        46.61                   NaN
# 534                          NaN                162.03
# 535                        65.10                118.10
# 536                        53.44                   NaN
#
#                                 Ad Topic Line  Clicked on Ad
# Number
# 533             Ergonomic methodical encoding              1
# 534         Compatible dedicated productivity              0
# 535            Up-sized real-time methodology              1
# 536     Up-sized next generation architecture              1
